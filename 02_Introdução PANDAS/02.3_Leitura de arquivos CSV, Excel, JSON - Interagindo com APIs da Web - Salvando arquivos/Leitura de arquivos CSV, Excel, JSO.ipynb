# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %% [markdown]
# ****QUESTÃO 1/A:

# %%
# 1) Seu código aqui
url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=RJ&tipo_interessado=Munic%C3%ADpio'

# %%
# 2) Seu código aqui
r = requests.get(url)

# %%
# 3) Seu código aqui
r.status_code
# Out:
# 200

# %%
pvl_mun_rj = r.json()
print(pvl_mun_rj['items'])
# Out:
# [{'id_pleito': 11053, 'tipo_interessado': 'Município', 'interessado': 'Macaé', 'cod_ibge': 3302403, 'uf': 'RJ', 'num_pvl': None, 'status': 'Deferido', 'num_processo': '17944.001346/2011-39', 'data_protocolo': '2011-11-29T02:00:00Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'PAC 2 - Pró-Moradia', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Caixa Econômica Federal', 'moeda': 'Real', 'valor': 48286602.68, 'pvl_assoc_divida': 1, 'pvl_contradado_credor': 0, 'data_status': '08/12/2011'}, {'id_pleito': 13817, 'tipo_interessado': 'Município', 'interessado': 'Valença', 'cod_ibge': 3306107, 'uf': 'RJ', 'num_pvl': None, 'status': 'Deferido', 'num_processo': '19405.000116/2004-56', 'data_protocolo': '2006-02-20T03:00:00Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'PMAT', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Banco do Brasil S/A', 'moeda': 'Real', 'valor': 1058400, 'pvl_assoc_divida': 0, 'pvl_contradado_credor': 0, 
# ...

# %%
df_pvl_mun_rj = pd.DataFrame(pvl_mun_rj['items'])

# %%
df_pvl_mun_rj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id_pleito              235 non-null    int64
#  1   tipo_interessado       235 non-null    object
#  2   interessado            235 non-null    object
#  3   cod_ibge               235 non-null    int64
#  4   uf                     235 non-null    object
#  5   num_pvl                58 non-null     object
#  6   status                 235 non-null    object
#  7   num_processo           218 non-null    object
#  8   data_protocolo         218 non-null    object
#  9   tipo_operacao          235 non-null    object
#  10  finalidade             235 non-null    object
#  11  tipo_credor            235 non-null    object
#  12  credor                 235 non-null    object
#  13  moeda                  235 non-null    object
# ...

# %%
df_pvl_mun_rj.head()
# Out:
#    id_pleito tipo_interessado        interessado  cod_ibge  uf num_pvl  \
# 0      11053        Município              Macaé   3302403  RJ    None
# 1      13817        Município            Valença   3306107  RJ    None
# 2      10482        Município    Duque de Caxias   3301702  RJ    None
# 3      13229        Município      Nova Friburgo   3303401  RJ    None
# 4      11022        Município  Casimiro de Abreu   3301306  RJ    None
#
#          status          num_processo        data_protocolo  \
# 0      Deferido  17944.001346/2011-39  2011-11-29T02:00:00Z
# 1      Deferido  19405.000116/2004-56  2006-02-20T03:00:00Z
# 2  Regularizado  17944.001210/2012-18  2020-04-13T03:00:00Z
# 3      Deferido  17944.001968/2006-08  2007-01-18T02:00:00Z
# 4      Deferido  17944.001338/2011-92  2012-04-18T03:00:00Z
#
#                  tipo_operacao  \
# 0  Operação contratual interna
# 1  Operação contratual interna
# 2  Operação contratual interna
# 3  Operação contratual interna
# ...

# %%
df_pvl_mun_rj['status']
# Out:
# 0          Deferido
# 1          Deferido
# 2      Regularizado
# 3          Deferido
# 4          Deferido
#            ...
# 230       Arquivado
# 231        Deferido
# 232        Deferido
# 233        Deferido
# 234        Deferido
# Name: status, Length: 235, dtype: object

# %%
df_pvl_mun_rj.status.unique()
# Out:
# array(['Deferido', 'Regularizado', 'Arquivado',
#        'Arquivado por decurso de prazo', 'Arquivado a pedido',
#        'Encaminhado à PGFN com manifestação técnica favorável',
#        'Deferido (PVL-IF)', 'Em retificação pelo interessado',
#        'Pendente de regularização',
#        'Em retificação pelo interessado (PVL-IF)'], dtype=object)

# %% [markdown]
# ****QUESTÃO 1/B:

# %%
df_pvl_mun_rj.status.value_counts()
# Out:
# Deferido                                                 94
# Arquivado                                                53
# Regularizado                                             25
# Arquivado por decurso de prazo                           23
# Deferido (PVL-IF)                                        16
# Encaminhado à PGFN com manifestação técnica favorável    13
# Arquivado a pedido                                        6
# Em retificação pelo interessado                           3
# Pendente de regularização                                 1
# Em retificação pelo interessado (PVL-IF)                  1
# Name: status, dtype: int64

# %% [markdown]
# ****QUESTÃO 1/C:

# %%
pg

# %%
ano_status
# Out:
# ['2011',
#  '2006',
#  '2020',
#  '2007',
#  '2012',
#  '2008',
#  '2010',
#  '2009',
#  '2007',
#  '2002',
#  '2012',
#  '2013',
#  '2007',
#  '2008',
#  '2011',
#  '2012',
#  '2014',
#  '2012',
#  '2010',
#  '2007',
#  '2015',
#  '2008',
#  '2011',
#  '2008',
#  '2009',
#  '2011',
#  '2008',
#  '2007',
#  '2019',
#  '2019',
#  '2013',
#  '2011',
#  '2015',
#  '2010',
#  '2014',
#  '2008',
#  '2014',
#  '2017',
#  '2008',
#  '2007',
#  '2015',
#  '2008',
#  '2014',
#  '2007',
#  '2014',
#  '2007',
#  '2008',
#  '2007',
#  '2008',
#  '2009',
#  '2007',
#  '2008',
#  '2015',
#  '2011',
#  '2013',
#  '2008',
#  '2014',
#  '2010',
#  '2014',
#  '2012',
#  '2007',
#  '2020',
#  '2013',
#  '2002',
#  '2007',
#  '2008',
#  '2007',
#  '2010',
#  '2008',
#  '2013',
#  '2006',
#  '2006',
#  '2007',
#  '2007',
#  '2014',
#  '2008',
#  '2006',
#  '2010',
#  '2013',
#  '2013',
#  '2007',
#  '2019',
#  '2008',
#  '2012',
#  '2020',
#  '2021',
#  '2021',
#  '2008',
#  '2021',
#  '2007',
# ...

# %%
df_pvl_mun_rj['ano_status']=ano_status
freq = df_pvl_mun_rj['ano_status_df'].value_counts()
print('Frequência por Ano')
print(freq)
# Out:
# Frequência por Ano
# 2008    37
# 2007    29
# 2014    20
# 2010    19
# 2019    17
# 2013    15
# 2020    15
# 2022    14
# 2012    13
# 2011    10
# 2015     9
# 2009     9
# 2017     5
# 2021     5
# 2006     4
# 2002     4
# 2016     4
# 2018     4
# 2004     1
# 2003     1
# Name: ano_status_df, dtype: int64

# %%
df_pvl_mun_rj
# Out:
#      id_pleito tipo_interessado        interessado  cod_ibge  uf  \
# 0        11053        Município              Macaé   3302403  RJ
# 1        13817        Município            Valença   3306107  RJ
# 2        10482        Município    Duque de Caxias   3301702  RJ
# 3        13229        Município      Nova Friburgo   3303401  RJ
# 4        11022        Município  Casimiro de Abreu   3301306  RJ
# ..         ...              ...                ...       ...  ..
# 230      10637        Município        Teresópolis   3305802  RJ
# 231      42829        Município    Duque de Caxias   3301702  RJ
# 232      26368        Município     Rio de Janeiro   3304557  RJ
# 233       5180        Município        Nova Iguaçu   3303500  RJ
# 234       5285        Município        São Gonçalo   3304904  RJ
#
#                   num_pvl        status          num_processo  \
# 0                    None      Deferido  17944.001346/2011-39
# ...

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %% [markdown]
# ****QUESTÃO 2/A:

# %%
#1) Seu código aqui
df_pvl_mun_rj.head()
# Out:
#    id_pleito tipo_interessado      interessado  cod_ibge  uf num_pvl  \
# 0      11501        Município     Belford Roxo   3300456  RJ    None
# 1       6388        Município         Itaboraí   3301900  RJ    None
# 2      11034        Município           Quatis   3304128  RJ    None
# 3      11697        Município  Duque de Caxias   3301702  RJ    None
# 4      13036        Município          Niterói   3303302  RJ    None
#
#                                               status          num_processo  \
# 0  Encaminhado à PGFN com manifestação técnica fa...  17944.001463/2007-16
# 1                                       Regularizado  17944.000334/2012-78
# 2                                          Arquivado  17944.001342/2009-36
# 3                                          Arquivado  17944.001505/2008-08
# 4                                       Regularizado  17944.001891/2006-68
#
#          data_protocolo                                      tipo_operacao  \
# ...

# %%
# 2) Seu código aqui
df_pvl_mun_rj['interessado'].value_counts()
# Out:
# Rio de Janeiro            41
# Resende                   15
# Nova Iguaçu               14
# Duque de Caxias           11
# Niterói                    9
#                           ..
# Varre-Sai                  1
# Duas Barras                1
# Silva Jardim               1
# Santo Antônio de Pádua     1
# Cachoeiras de Macacu       1
# Name: interessado, Length: 61, dtype: int64

# %%
# 3) Seu código aqui
df_pvl_mun_rj['tipo_interessado'].value_counts()
# Out:
# Município    235
# Name: tipo_interessado, dtype: int64

# %%
# 4) Seu código aqui
url1 = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=RJ&tipo_interessado=Estado'

# %%
r1 = requests.get(url1)

# %%
r1.status_code
# Out:
# 200

# %%
pvl_est_rj = r1.json()
print(pvl_est_rj['items'])
# Out:
# [{'id_pleito': 12375, 'tipo_interessado': 'Estado', 'interessado': 'Rio de Janeiro', 'cod_ibge': 33, 'uf': 'RJ', 'num_pvl': None, 'status': 'Encaminhado à PGFN com manifestação técnica favorável', 'num_processo': '17944.001671/2011-00', 'data_protocolo': '2011-10-18T02:00:00Z', 'tipo_operacao': 'Operação contratual externa (com garantia da União)', 'finalidade': 'Preservação e recuperação ambiental', 'tipo_credor': 'Instituição Financeira Internacional', 'credor': 'Banco Interamericano de Desenvolvimento', 'moeda': 'Dólar dos EUA', 'valor': 451980000, 'pvl_assoc_divida': 1, 'pvl_contradado_credor': 0, 'data_status': '27/12/2011'}, {'id_pleito': 10562, 'tipo_interessado': 'Estado', 'interessado': 'Rio de Janeiro', 'cod_ibge': 33, 'uf': 'RJ', 'num_pvl': None, 'status': 'Encaminhado à PGFN com manifestação técnica favorável', 'num_processo': '17944.001228/2013-92', 'data_protocolo': '2013-10-22T02:00:00Z', 'tipo_operacao': 'Operação contratual externa (com garantia da União)', 'finalida
# ...

# %%
df_pvl_est_rj = pd.DataFrame(pvl_est_rj['items'])

# %%
df_pvl_est_rj
# Out:
#     id_pleito tipo_interessado     interessado  cod_ibge  uf  \
# 0       12375           Estado  Rio de Janeiro        33  RJ
# 1       10562           Estado  Rio de Janeiro        33  RJ
# 2       13560           Estado  Rio de Janeiro        33  RJ
# 3        7080           Estado  Rio de Janeiro        33  RJ
# 4        8556           Estado  Rio de Janeiro        33  RJ
# 5       10002           Estado  Rio de Janeiro        33  RJ
# 6        9750           Estado  Rio de Janeiro        33  RJ
# 7       10673           Estado  Rio de Janeiro        33  RJ
# 8       11306           Estado  Rio de Janeiro        33  RJ
# 9       13364           Estado  Rio de Janeiro        33  RJ
# 10       8528           Estado  Rio de Janeiro        33  RJ
# 11       5923           Estado  Rio de Janeiro        33  RJ
# 12       7057           Estado  Rio de Janeiro        33  RJ
# 13      13483           Estado  Rio de Janeiro        33  RJ
# ...

# %%
df_pvl_est_rj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id_pleito              52 non-null     int64
#  1   tipo_interessado       52 non-null     object
#  2   interessado            52 non-null     object
#  3   cod_ibge               52 non-null     int64
#  4   uf                     52 non-null     object
#  5   num_pvl                3 non-null      object
#  6   status                 52 non-null     object
#  7   num_processo           52 non-null     object
#  8   data_protocolo         52 non-null     object
#  9   tipo_operacao          52 non-null     object
#  10  finalidade             52 non-null     object
#  11  tipo_credor            52 non-null     object
#  12  credor                 52 non-null     object
#  13  moeda                  52 non-null     object
# ...

# %%
df_merge_est_mun_rj = pd.merge(df_pvl_mun_rj, df_pvl_est_rj, how = 'outer')

# %%
df_merge_est_mun_rj
# Out:
#      id_pleito tipo_interessado      interessado  cod_ibge  uf num_pvl  \
# 0        11501        Município     Belford Roxo   3300456  RJ    None
# 1         6388        Município         Itaboraí   3301900  RJ    None
# 2        11034        Município           Quatis   3304128  RJ    None
# 3        11697        Município  Duque de Caxias   3301702  RJ    None
# 4        13036        Município          Niterói   3303302  RJ    None
# ..         ...              ...              ...       ...  ..     ...
# 282       5645           Estado   Rio de Janeiro        33  RJ    None
# 283       5640           Estado   Rio de Janeiro        33  RJ    None
# 284       5630           Estado   Rio de Janeiro        33  RJ    None
# 285       5635           Estado   Rio de Janeiro        33  RJ    None
# 286       7255           Estado   Rio de Janeiro        33  RJ    None
#
#                                                 status          num_processo  \
# ...

# %%
df_merge_est_mun_rj['tipo_interessado'].value_counts()
# Out:
# Município    235
# Estado        52
# Name: tipo_interessado, dtype: int64

# %% [markdown]
# ****FIQUEI COM DÚVIDAS NESSE ITEM

# %%
consulta_uf = input('Informe o estado:')
consulta_interessado = input('Informe o interessado, Estado ou Município:')
df_merge_est_mun_rj.loc[(df_merge_est_mun_rj['uf'] == consulta_uf) & (df_merge_est_mun_rj['tipo_interessado'] == consulta_interessado)]
# Out:
# Informe o estado:RJ
# Informe o interessado, Estado ou Município:Município
#      id_pleito tipo_interessado      interessado  cod_ibge  uf  \
# 0        11501        Município     Belford Roxo   3300456  RJ
# 1         6388        Município         Itaboraí   3301900  RJ
# 2        11034        Município           Quatis   3304128  RJ
# 3        11697        Município  Duque de Caxias   3301702  RJ
# 4        13036        Município          Niterói   3303302  RJ
# ..         ...              ...              ...       ...  ..
# 230       5470        Município   Rio de Janeiro   3304557  RJ
# 231       9806        Município      Teresópolis   3305802  RJ
# 232       5763        Município   Rio de Janeiro   3304557  RJ
# 233      34098        Município          Resende   3304201  RJ
# 234      11032        Município       Petrópolis   3303906  RJ
#
#                   num_pvl                                             status  \
# ...

# %% [markdown]
# ****QUESTÃO 2/B:

# %%
url2 = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=MG&tipo_interessado=Estado'

# %%
r2 = requests.get(url2)

# %%
r2.status_code

# %%
pvl_est_mg = r2.json()
print(pvl_est_mg['items'])

# %%
df_pvl_est_mg = pd.DataFrame(pvl_est_mg['items'])

# %%
df_pvl_est_mg

# %%
df_pvl_est_mg.status.value_counts()

# %% [markdown]
# ****QUESTÃO 2/C:

# %%
url3 = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=BA&tipo_interessado=Munic%C3%ADpio'

# %%
r3 = requests.get(url3)

# %%
r3.status_code

# %%
pvl_mun_ba = r3.json()

# %%
df_pvl_mun_ba = pd.DataFrame(pvl_mun_ba['items'])

# %%
df_pvl_mun_ba

# %%
df_pvl_mun_ba.interessado.value_counts()

# %% [markdown]
# ****QUESTÃO 2/D:

# %%
url4 = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=BA&tipo_interessado=Estado'

# %%
r4 = requests.get(url4)

# %%
r4.status_code

# %%
pvl_est_ba = r4.json()

# %%
pvl_est_ba

# %%
df_pvl_est_ba = pd.DataFrame(pvl_est_ba['items'])

# %%
df_pvl_est_ba

# %%
df_pvl_est_ba.to_csv('dataframe_PVL_Estado_Bahia.csv')
